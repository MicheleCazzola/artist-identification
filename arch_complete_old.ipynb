# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from torchvision.models import resnet18
from skimage.feature import hog
import numpy as np

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        bottleneck_channels = out_channels // 4

        self.conv1 = nn.Conv2d(in_channels, bottleneck_channels, kernel_size=1, stride=stride)
        self.bn1 = nn.BatchNorm2d(bottleneck_channels)
        self.conv2 = nn.Conv2d(bottleneck_channels, bottleneck_channels, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(bottleneck_channels)
        self.conv3 = nn.Conv2d(bottleneck_channels, out_channels, kernel_size=1)
        self.bn3 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

class ROIsProposal(nn.Module):
    def __init__(self, use_stn=True):
        super(ROIsProposal, self).__init__()
        self.use_stn = use_stn
        if use_stn:
            self.stn1 = self._make_stn()
            self.stn2 = self._make_stn()

    def _make_stn(self):
        # Using ResNet-18 as the localization network
        model = resnet18(weights="IMAGENET1K_V1")
        model.fc = nn.Linear(model.fc.in_features, 6)
        return model

    def forward(self, x):
        # Assume x is a batch of images resized to (512, 512)
        crops = []
        if self.use_stn:
            theta1 = self.stn1(x)
            grid1 = F.affine_grid(theta1.view(-1, 2, 3), size=(x.size(0), 3, 224, 224), align_corners=False)
            crops.append(F.grid_sample(x, grid1, align_corners=False))

            theta2 = self.stn2(x)
            grid2 = F.affine_grid(theta2.view(-1, 2, 3), size=(x.size(0), 3, 224, 224), align_corners=False)
            crops.append(F.grid_sample(x, grid2, align_corners=False))

        else:
            # Random cropping logic
            for _ in range(2):
                i, j, h, w = T.RandomCrop.get_params(x, output_size=(224, 224))
                crop = T.functional.crop(x, i, j, h, w)
                crops.append(crop)

        # Low-resolution crop
        low_res = F.interpolate(x, size=(256, 256), mode='bilinear', align_corners=False)
        i, j, h, w = T.RandomCrop.get_params(low_res, output_size=(224, 224))
        crops.append(T.functional.crop(low_res, i, j, h, w))

        return crops

class HandCraftedFeatures(nn.Module):
    def __init__(self):
        super(HandCraftedFeatures, self).__init__()

    def forward(self, x):
        # Convert tensor to numpy for feature extraction
        x_np = x.cpu().numpy().transpose(0, 2, 3, 1)  # N, H, W, C
        features = []
        for img in x_np:
            gray = 0.299 * img[:, :, 0] + 0.587 * img[:, :, 1] + 0.114 * img[:, :, 2]
            hog_features = hog(gray, orientations=6, pixels_per_cell=(16, 16),
                               cells_per_block=(2, 2), block_norm='L2-Hys')
            features.append(hog_features)
        features = np.array(features)
        return torch.tensor(features, dtype=torch.float32, device=x.device)

class MultibranchNetwork(nn.Module):
    def __init__(self, use_stn=True):
        super(MultibranchNetwork, self).__init__()

        # ROI proposal module
        self.roi_proposal = ROIsProposal(use_stn=use_stn)

        # Shared layers for three branches
        self.branch1 = self._make_branch()
        self.branch2 = self._make_branch()
        self.branch3 = self._make_branch()

        # Hand-crafted feature injection
        self.hand_crafted_features = HandCraftedFeatures()

        # Concatenation processing
        self.join_layer = ResidualBlock(768, 256, stride=1)

        # Common deep layers
        self.resblock1 = ResidualBlock(256, 512, stride=2)
        self.resblock2 = self._make_residual_block(512, 1024, num_blocks=5, stride=2)
        self.resblock3 = self._make_residual_block(1024, 2048, num_blocks=3, stride=2)

        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        # Task-specific fully connected layers
        #self.fc_artist = nn.Linear(2048 + 4056, 1508)  # HOG feature size is 3780
        # self.fc_style = nn.Linear(2048 + 4056, 125)
        # self.fc_genre = nn.Linear(2048 + 4056, 41)
        #self.fc_artist = nn.Linear(2048 + 4056, 1508)  # HOG feature size is 3780
        self.fc_artist = nn.Linear(2048 + 4056, 1508)

    def _make_branch(self):
        layers = [
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1),
            self._make_residual_block(64, 256, num_blocks=3, stride=1)
        ]
        return nn.Sequential(*layers)

    def _make_residual_block(self, in_channels, out_channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for s in strides:
            layers.append(ResidualBlock(in_channels, out_channels, stride=s))
            in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # ROI proposal
        crops = self.roi_proposal(x)
        x1, x2, x3 = crops

        # Process each branch
        out1 = self.branch1(x1)
        out2 = self.branch2(x2)
        out3 = self.branch3(x3)

        # Concatenate feature maps along the channel dimension
        out = torch.cat([out1, out2, out3], dim=1)
        out = self.join_layer(out)

        # Common processing
        out = self.resblock1(out)
        out = self.resblock2(out)
        out = self.resblock3(out)
        out = self.avg_pool(out)
        out = torch.flatten(out, 1)

        # Hand-crafted features
        crop_size = 224
        x_cropped = T.CenterCrop(crop_size)(x)
        hand_crafted = self.hand_crafted_features(x_cropped)

        print(x.shape, out.shape, hand_crafted.shape)
        out = torch.cat([out, hand_crafted], dim=1)

        print(out.shape)

        # Task-specific outputs
        artist = self.fc_artist(out)

        return artist

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
model = MultibranchNetwork(use_stn=True).to(DEVICE)

# %%
count_params = lambda pl: sum(p.numel() for p in pl)

# %%
count_params(model.parameters())
# Out:
# 53893456

# %%
from pytorch_memlab import MemReporter
x = torch.randn(4, 3, 512, 512).to(DEVICE)
with torch.no_grad():
    r = model(x)
    
m = MemReporter()
m.report()
# Out:
# torch.Size([4, 3, 512, 512]) torch.Size([4, 2048]) torch.Size([4, 4056])
# torch.Size([4, 6104])
# Element type                                            Size  Used MEM
# -------------------------------------------------------------------------------
# Storage on cpu
# Parameter0                                           (2048,)     8.00K
# Parameter1                                           (2048,)     8.00K
# Tensor2                                              (2048,)     8.00K
# Tensor3                                              (2048,)     8.00K
# Tensor4                                                 (1,)   512.00B
# Parameter5                                 (512, 2048, 1, 1)     4.00M
# Parameter6                                            (512,)     2.00K
# Parameter7                                            (512,)     2.00K
# Parameter8                                            (512,)     2.00K
# Tensor9                                               (512,)     2.00K
# Tensor10                                              (512,)     2.00K
# Tensor11                                                (1,)   512.00B
# Parameter12                                 (512, 512, 3, 3)     9.00M
# Parameter13                                           (512,)     2.00K
# Parameter14                                           (512,)     2.00K
# Parameter15                                           (512,)     2.00K
# Tensor16                                              (512,)     2.00K
# Tensor17                                              (512,)     2.00K
# Tensor18                                                (1,)   512.00B
# Parameter19                                (2048, 512, 1, 1)     4.00M
# Parameter20                                          (2048,)     8.00K
# Parameter21                                          (2048,)     8.00K
# Parameter22                                          (2048,)     8.00K
# Tensor23                                             (2048,)     8.00K
# Tensor24                                             (2048,)     8.00K
# Tensor25                                                (1,)   512.00B
# Parameter26                                     (1508, 6104)    35.11M
# Parameter27                                          (1508,)     6.00K
# Tensor28                                    (4, 3, 512, 512)    12.00M
# Tensor29                                           (4, 1508)    24.00K
# Parameter30                                          (1024,)     4.00K
# Tensor31                                             (1024,)     4.00K
# Tensor32                                                (1,)   512.00B
# Parameter33                                           (512,)     2.00K
# Tensor34                                              (512,)     2.00K
# Tensor35                                                (1,)   512.00B
# Parameter36                                           (512,)     2.00K
# Parameter37                                           (512,)     2.00K
# Tensor38                                              (512,)     2.00K
# Tensor39                                                (1,)   512.00B
# Parameter40                                          (2048,)     8.00K
# Parameter41                                          (2048,)     8.00K
# Tensor42                                             (2048,)     8.00K
# Tensor43                                                (1,)   512.00B
# Parameter44                                           (512,)     2.00K
# Tensor45                                              (512,)     2.00K
# Tensor46                                                (1,)   512.00B
# Parameter47                                           (512,)     2.00K
# Parameter48                                           (512,)     2.00K
# Tensor49                                              (512,)     2.00K
# Tensor50                                                (1,)   512.00B
# Parameter51                                          (2048,)     8.00K
# Parameter52                                          (1024,)     4.00K
# Tensor53                                             (1024,)     4.00K
# Parameter54                                           (512,)     2.00K
# Tensor55                                              (512,)     2.00K
# Parameter56                                 (512, 512, 3, 3)     9.00M
# Parameter57                                           (512,)     2.00K
# Tensor58                                              (512,)     2.00K
# Parameter59                                (2048, 512, 1, 1)     4.00M
# Parameter60                                          (2048,)     8.00K
# Tensor61                                             (2048,)     8.00K
# Parameter62                                           (512,)     2.00K
# Tensor63                                              (512,)     2.00K
# Parameter64                                 (512, 512, 3, 3)     9.00M
# Parameter65                                           (512,)     2.00K
# Tensor66                                              (512,)     2.00K
# Parameter67                                (2048, 512, 1, 1)     4.00M
# Parameter68                                (512, 1024, 1, 1)     2.00M
# Parameter69                                           (512,)     2.00K
# Parameter70                               (2048, 1024, 1, 1)     8.00M
# Parameter71                                          (2048,)     8.00K
# Parameter72                                          (2048,)     8.00K
# Parameter73                                          (2048,)     8.00K
# Tensor74                                             (2048,)     8.00K
# Tensor75                                             (2048,)     8.00K
# Tensor76                                                (1,)   512.00B
# Parameter77                                (512, 2048, 1, 1)     4.00M
# Parameter78                                           (512,)     2.00K
# Parameter79                                (256, 1024, 1, 1)     1.00M
# Parameter80                                           (256,)     1.00K
# Parameter81                                           (256,)     1.00K
# Parameter82                                           (256,)     1.00K
# Tensor83                                              (256,)     1.00K
# Tensor84                                              (256,)     1.00K
# Tensor85                                                (1,)   512.00B
# Parameter86                                 (256, 256, 3, 3)     2.25M
# Parameter87                                           (256,)     1.00K
# Parameter88                                           (256,)     1.00K
# Parameter89                                           (256,)     1.00K
# Tensor90                                              (256,)     1.00K
# Tensor91                                              (256,)     1.00K
# Tensor92                                                (1,)   512.00B
# Parameter93                                (1024, 256, 1, 1)     1.00M
# Parameter94                                          (1024,)     4.00K
# Parameter95                                          (1024,)     4.00K
# Parameter96                                          (1024,)     4.00K
# Tensor97                                             (1024,)     4.00K
# Tensor98                                             (1024,)     4.00K
# Tensor99                                                (1,)   512.00B
# Parameter100                               (256, 1024, 1, 1)     1.00M
# Parameter101                                          (256,)     1.00K
# Parameter102                                          (256,)     1.00K
# Parameter103                                          (256,)     1.00K
# Tensor104                                             (256,)     1.00K
# Tensor105                                             (256,)     1.00K
# Tensor106                                               (1,)   512.00B
# Parameter107                                (256, 256, 3, 3)     2.25M
# Parameter108                                          (256,)     1.00K
# Parameter109                                          (256,)     1.00K
# Parameter110                                          (256,)     1.00K
# Tensor111                                             (256,)     1.00K
# Tensor112                                             (256,)     1.00K
# Tensor113                                               (1,)   512.00B
# Parameter114                               (1024, 256, 1, 1)     1.00M
# Parameter115                                         (1024,)     4.00K
# Parameter116                                         (1024,)     4.00K
# Parameter117                                         (1024,)     4.00K
# Tensor118                                            (1024,)     4.00K
# Tensor119                                            (1024,)     4.00K
# Tensor120                                               (1,)   512.00B
# Parameter121                                           (64,)   512.00B
# Tensor122                                              (64,)   512.00B
# Parameter123                                           (64,)   512.00B
# Tensor124                                              (64,)   512.00B
# Parameter125                                   (64, 3, 7, 7)    37.00K
# Parameter126                                   (64, 3, 7, 7)    37.00K
# Parameter127                                           (64,)   512.00B
# Parameter128                                           (64,)   512.00B
# Tensor129                                              (64,)   512.00B
# Tensor130                                              (64,)   512.00B
# Parameter131                                        (6, 512)    12.00K
# Parameter132                                            (6,)   512.00B
# Parameter133                                  (64, 64, 3, 3)   144.00K
# Parameter134                                           (64,)   512.00B
# Parameter135                                           (64,)   512.00B
# Tensor136                                              (64,)   512.00B
# Tensor137                                              (64,)   512.00B
# Parameter138                                  (64, 64, 3, 3)   144.00K
# Parameter139                                           (64,)   512.00B
# Parameter140                                           (64,)   512.00B
# Tensor141                                              (64,)   512.00B
# Tensor142                                              (64,)   512.00B
# Parameter143                                  (64, 64, 3, 3)   144.00K
# Parameter144                                           (64,)   512.00B
# Parameter145                                           (64,)   512.00B
# Tensor146                                              (64,)   512.00B
# Tensor147                                              (64,)   512.00B
# Parameter148                                  (64, 64, 3, 3)   144.00K
# Parameter149                                           (64,)   512.00B
# Parameter150                                           (64,)   512.00B
# Tensor151                                              (64,)   512.00B
# Tensor152                                              (64,)   512.00B
# Parameter153                                 (128, 64, 3, 3)   288.00K
# Parameter154                                          (128,)   512.00B
# Parameter155                                          (128,)   512.00B
# Tensor156                                             (128,)   512.00B
# Tensor157                                             (128,)   512.00B
# Parameter158                                (128, 128, 3, 3)   576.00K
# Parameter159                                          (128,)   512.00B
# Parameter160                                          (128,)   512.00B
# Tensor161                                             (128,)   512.00B
# Tensor162                                             (128,)   512.00B
# Parameter163                                (128, 128, 3, 3)   576.00K
# Parameter164                                          (128,)   512.00B
# Parameter165                                          (128,)   512.00B
# Tensor166                                             (128,)   512.00B
# Tensor167                                             (128,)   512.00B
# Parameter168                                (128, 128, 3, 3)   576.00K
# Parameter169                                          (128,)   512.00B
# Parameter170                                          (128,)   512.00B
# Tensor171                                             (128,)   512.00B
# Tensor172                                             (128,)   512.00B
# Parameter173                                 (128, 64, 1, 1)    32.00K
# Parameter174                                          (128,)   512.00B
# Parameter175                                          (128,)   512.00B
# Tensor176                                             (128,)   512.00B
# Tensor177                                             (128,)   512.00B
# Parameter178                                  (64, 64, 3, 3)   144.00K
# Parameter179                                           (64,)   512.00B
# Parameter180                                           (64,)   512.00B
# Tensor181                                              (64,)   512.00B
# Tensor182                                              (64,)   512.00B
# Parameter183                                  (64, 64, 3, 3)   144.00K
# Parameter184                                           (64,)   512.00B
# Parameter185                                           (64,)   512.00B
# Tensor186                                              (64,)   512.00B
# Tensor187                                              (64,)   512.00B
# Parameter188                                  (64, 64, 3, 3)   144.00K
# Parameter189                                           (64,)   512.00B
# Parameter190                                           (64,)   512.00B
# Tensor191                                              (64,)   512.00B
# Tensor192                                              (64,)   512.00B
# Parameter193                                  (64, 64, 3, 3)   144.00K
# Parameter194                                           (64,)   512.00B
# Parameter195                                           (64,)   512.00B
# Tensor196                                              (64,)   512.00B
# Tensor197                                              (64,)   512.00B
# Parameter198                                 (128, 64, 3, 3)   288.00K
# Parameter199                                          (128,)   512.00B
# Parameter200                                          (128,)   512.00B
# Tensor201                                             (128,)   512.00B
# Tensor202                                             (128,)   512.00B
# Parameter203                                (128, 128, 3, 3)   576.00K
# Parameter204                                          (128,)   512.00B
# Parameter205                                          (128,)   512.00B
# Tensor206                                             (128,)   512.00B
# Tensor207                                             (128,)   512.00B
# Parameter208                                (128, 128, 3, 3)   576.00K
# Parameter209                                          (128,)   512.00B
# Parameter210                                          (128,)   512.00B
# Tensor211                                             (128,)   512.00B
# Tensor212                                             (128,)   512.00B
# Parameter213                                (128, 128, 3, 3)   576.00K
# Parameter214                                          (128,)   512.00B
# Parameter215                                          (128,)   512.00B
# Tensor216                                             (128,)   512.00B
# Tensor217                                             (128,)   512.00B
# Parameter218                                (256, 128, 3, 3)     1.12M
# Parameter219                                          (256,)     1.00K
# Parameter220                                          (256,)     1.00K
# Tensor221                                             (256,)     1.00K
# Tensor222                                             (256,)     1.00K
# Parameter223                                (256, 256, 3, 3)     2.25M
# Parameter224                                          (256,)     1.00K
# Parameter225                                          (256,)     1.00K
# Tensor226                                             (256,)     1.00K
# Tensor227                                             (256,)     1.00K
# Parameter228                                (256, 256, 3, 3)     2.25M
# Parameter229                                          (256,)     1.00K
# Parameter230                                          (256,)     1.00K
# Tensor231                                             (256,)     1.00K
# Tensor232                                             (256,)     1.00K
# Parameter233                                (256, 256, 3, 3)     2.25M
# Parameter234                                          (256,)     1.00K
# Parameter235                                          (256,)     1.00K
# Tensor236                                             (256,)     1.00K
# Tensor237                                             (256,)     1.00K
# Parameter238                                (512, 256, 3, 3)     4.50M
# Parameter239                                          (512,)     2.00K
# Parameter240                                          (512,)     2.00K
# Tensor241                                             (512,)     2.00K
# Tensor242                                             (512,)     2.00K
# Parameter243                                (512, 512, 3, 3)     9.00M
# Parameter244                                          (512,)     2.00K
# Parameter245                                          (512,)     2.00K
# Tensor246                                             (512,)     2.00K
# Tensor247                                             (512,)     2.00K
# Parameter248                                (512, 512, 3, 3)     9.00M
# Parameter249                                          (512,)     2.00K
# Parameter250                                          (512,)     2.00K
# Tensor251                                             (512,)     2.00K
# Tensor252                                             (512,)     2.00K
# Parameter253                                (512, 512, 3, 3)     9.00M
# Parameter254                                          (512,)     2.00K
# Parameter255                                          (512,)     2.00K
# Tensor256                                             (512,)     2.00K
# Tensor257                                             (512,)     2.00K
# Parameter258                                 (128, 64, 1, 1)    32.00K
# Parameter259                                          (128,)   512.00B
# Parameter260                                          (128,)   512.00B
# Tensor261                                             (128,)   512.00B
# Tensor262                                             (128,)   512.00B
# Parameter263                                (256, 128, 1, 1)   128.00K
# Parameter264                                          (256,)     1.00K
# Parameter265                                          (256,)     1.00K
# Tensor266                                             (256,)     1.00K
# Tensor267                                             (256,)     1.00K
# Parameter268                                (512, 256, 1, 1)   512.00K
# Parameter269                                          (512,)     2.00K
# Parameter270                                          (512,)     2.00K
# Tensor271                                             (512,)     2.00K
# Tensor272                                             (512,)     2.00K
# Parameter273                                (256, 128, 1, 1)   128.00K
# Parameter274                                (256, 128, 3, 3)     1.12M
# Parameter275                                          (256,)     1.00K
# Parameter276                                          (256,)     1.00K
# Tensor277                                             (256,)     1.00K
# Tensor278                                             (256,)     1.00K
# Parameter279                                (256, 256, 3, 3)     2.25M
# Parameter280                                          (256,)     1.00K
# Parameter281                                          (256,)     1.00K
# Tensor282                                             (256,)     1.00K
# Tensor283                                             (256,)     1.00K
# Parameter284                                (256, 256, 3, 3)     2.25M
# Parameter285                                          (256,)     1.00K
# Parameter286                                          (256,)     1.00K
# Tensor287                                             (256,)     1.00K
# Tensor288                                             (256,)     1.00K
# Parameter289                                (256, 256, 3, 3)     2.25M
# Parameter290                                          (256,)     1.00K
# Parameter291                                          (256,)     1.00K
# Tensor292                                             (256,)     1.00K
# Tensor293                                             (256,)     1.00K
# Parameter294                                (512, 256, 3, 3)     4.50M
# Parameter295                                          (512,)     2.00K
# Parameter296                                          (512,)     2.00K
# Tensor297                                             (512,)     2.00K
# Tensor298                                             (512,)     2.00K
# Parameter299                                (512, 512, 3, 3)     9.00M
# Parameter300                                          (512,)     2.00K
# Parameter301                                          (512,)     2.00K
# Tensor302                                             (512,)     2.00K
# Tensor303                                             (512,)     2.00K
# Parameter304                                (512, 512, 3, 3)     9.00M
# Parameter305                                          (512,)     2.00K
# Parameter306                                          (512,)     2.00K
# Tensor307                                             (512,)     2.00K
# Tensor308                                             (512,)     2.00K
# Parameter309                                (512, 512, 3, 3)     9.00M
# Parameter310                                          (512,)     2.00K
# Parameter311                                          (512,)     2.00K
# Tensor312                                             (512,)     2.00K
# Tensor313                                             (512,)     2.00K
# Parameter314                                          (256,)     1.00K
# Parameter315                                          (256,)     1.00K
# Tensor316                                             (256,)     1.00K
# Tensor317                                             (256,)     1.00K
# Parameter318                                (512, 256, 1, 1)   512.00K
# Parameter319                                          (512,)     2.00K
# Parameter320                                          (512,)     2.00K
# Tensor321                                             (512,)     2.00K
# Tensor322                                             (512,)     2.00K
# Parameter323                                            (6,)   512.00B
# Parameter324                                        (6, 512)    12.00K
# Parameter325                                   (64, 3, 7, 7)    37.00K
# Parameter326                                           (64,)   512.00B
# Parameter327                                           (64,)   512.00B
# Parameter328                                           (64,)   512.00B
# Tensor329                                              (64,)   512.00B
# Tensor330                                              (64,)   512.00B
# Parameter331                                  (64, 64, 1, 1)    16.00K
# Parameter332                                           (64,)   512.00B
# Parameter333                                           (64,)   512.00B
# Parameter334                                           (64,)   512.00B
# Tensor335                                              (64,)   512.00B
# Tensor336                                              (64,)   512.00B
# Parameter337                                  (64, 64, 3, 3)   144.00K
# Parameter338                                           (64,)   512.00B
# Parameter339                                           (64,)   512.00B
# Parameter340                                           (64,)   512.00B
# Tensor341                                              (64,)   512.00B
# Tensor342                                              (64,)   512.00B
# Parameter343                                 (256, 64, 1, 1)    64.00K
# Parameter344                                          (256,)     1.00K
# Parameter345                                          (256,)     1.00K
# Parameter346                                          (256,)     1.00K
# Tensor347                                             (256,)     1.00K
# Tensor348                                             (256,)     1.00K
# Parameter349                                 (64, 256, 1, 1)    64.00K
# Parameter350                                           (64,)   512.00B
# Parameter351                                           (64,)   512.00B
# Parameter352                                           (64,)   512.00B
# Tensor353                                              (64,)   512.00B
# Tensor354                                              (64,)   512.00B
# Parameter355                                  (64, 64, 3, 3)   144.00K
# Parameter356                                           (64,)   512.00B
# Parameter357                                           (64,)   512.00B
# Parameter358                                           (64,)   512.00B
# Tensor359                                              (64,)   512.00B
# Tensor360                                              (64,)   512.00B
# Parameter361                                 (256, 64, 1, 1)    64.00K
# Parameter362                                          (256,)     1.00K
# Parameter363                                          (256,)     1.00K
# Parameter364                                          (256,)     1.00K
# Tensor365                                             (256,)     1.00K
# Tensor366                                             (256,)     1.00K
# Parameter367                                 (64, 256, 1, 1)    64.00K
# Parameter368                                           (64,)   512.00B
# Parameter369                                           (64,)   512.00B
# Parameter370                                           (64,)   512.00B
# Tensor371                                              (64,)   512.00B
# Tensor372                                              (64,)   512.00B
# Parameter373                                  (64, 64, 3, 3)   144.00K
# Parameter374                                           (64,)   512.00B
# Parameter375                                           (64,)   512.00B
# Parameter376                                           (64,)   512.00B
# Tensor377                                              (64,)   512.00B
# Tensor378                                              (64,)   512.00B
# Parameter379                                 (256, 64, 1, 1)    64.00K
# Parameter380                                          (256,)     1.00K
# Parameter381                                          (256,)     1.00K
# Parameter382                                          (256,)     1.00K
# Tensor383                                             (256,)     1.00K
# Tensor384                                             (256,)     1.00K
# Parameter385                                 (256, 64, 1, 1)    64.00K
# Parameter386                                          (256,)     1.00K
# Parameter387                                          (256,)     1.00K
# Parameter388                                          (256,)     1.00K
# Tensor389                                             (256,)     1.00K
# Tensor390                                             (256,)     1.00K
# Parameter391                                           (64,)   512.00B
# Parameter392                                           (64,)   512.00B
# Tensor393                                              (64,)   512.00B
# Tensor394                                              (64,)   512.00B
# Parameter395                                  (64, 64, 1, 1)    16.00K
# Parameter396                                           (64,)   512.00B
# Parameter397                                           (64,)   512.00B
# Parameter398                                           (64,)   512.00B
# Tensor399                                              (64,)   512.00B
# Tensor400                                              (64,)   512.00B
# Parameter401                                  (64, 64, 3, 3)   144.00K
# Parameter402                                           (64,)   512.00B
# Parameter403                                           (64,)   512.00B
# Parameter404                                           (64,)   512.00B
# Tensor405                                              (64,)   512.00B
# Tensor406                                              (64,)   512.00B
# Parameter407                                 (256, 64, 1, 1)    64.00K
# Parameter408                                          (256,)     1.00K
# Parameter409                                          (256,)     1.00K
# Parameter410                                          (256,)     1.00K
# Tensor411                                             (256,)     1.00K
# Tensor412                                             (256,)     1.00K
# Parameter413                                 (64, 256, 1, 1)    64.00K
# Parameter414                                           (64,)   512.00B
# Parameter415                                           (64,)   512.00B
# Parameter416                                           (64,)   512.00B
# Tensor417                                              (64,)   512.00B
# Tensor418                                              (64,)   512.00B
# Parameter419                                  (64, 64, 3, 3)   144.00K
# Parameter420                                           (64,)   512.00B
# Parameter421                                           (64,)   512.00B
# Parameter422                                           (64,)   512.00B
# Tensor423                                              (64,)   512.00B
# Tensor424                                              (64,)   512.00B
# Parameter425                                 (256, 64, 1, 1)    64.00K
# Parameter426                                          (256,)     1.00K
# Parameter427                                          (256,)     1.00K
# Parameter428                                          (256,)     1.00K
# Tensor429                                             (256,)     1.00K
# Tensor430                                             (256,)     1.00K
# Parameter431                                 (64, 256, 1, 1)    64.00K
# Parameter432                                           (64,)   512.00B
# Parameter433                                           (64,)   512.00B
# Parameter434                                           (64,)   512.00B
# Tensor435                                              (64,)   512.00B
# Tensor436                                              (64,)   512.00B
# Parameter437                                  (64, 64, 3, 3)   144.00K
# Parameter438                                           (64,)   512.00B
# Parameter439                                           (64,)   512.00B
# Parameter440                                           (64,)   512.00B
# Tensor441                                              (64,)   512.00B
# Tensor442                                              (64,)   512.00B
# Parameter443                                 (256, 64, 1, 1)    64.00K
# Parameter444                                          (256,)     1.00K
# Parameter445                                          (256,)     1.00K
# Parameter446                                          (256,)     1.00K
# Tensor447                                             (256,)     1.00K
# Tensor448                                             (256,)     1.00K
# Parameter449                                 (256, 64, 1, 1)    64.00K
# Parameter450                                          (256,)     1.00K
# Parameter451                                          (256,)     1.00K
# Parameter452                                          (256,)     1.00K
# Tensor453                                             (256,)     1.00K
# Tensor454                                             (256,)     1.00K
# Parameter455                                  (64, 64, 1, 1)    16.00K
# Parameter456                                           (64,)   512.00B
# Parameter457                                           (64,)   512.00B
# Parameter458                                           (64,)   512.00B
# Tensor459                                              (64,)   512.00B
# Tensor460                                              (64,)   512.00B
# Parameter461                                  (64, 64, 3, 3)   144.00K
# Parameter462                                           (64,)   512.00B
# Parameter463                                           (64,)   512.00B
# Parameter464                                           (64,)   512.00B
# Tensor465                                              (64,)   512.00B
# Tensor466                                              (64,)   512.00B
# Parameter467                                 (256, 64, 1, 1)    64.00K
# Parameter468                                          (256,)     1.00K
# Parameter469                                          (256,)     1.00K
# Parameter470                                          (256,)     1.00K
# Tensor471                                             (256,)     1.00K
# Tensor472                                             (256,)     1.00K
# Parameter473                                 (64, 256, 1, 1)    64.00K
# Parameter474                                           (64,)   512.00B
# Parameter475                                           (64,)   512.00B
# Parameter476                                           (64,)   512.00B
# Tensor477                                              (64,)   512.00B
# Tensor478                                              (64,)   512.00B
# Parameter479                                  (64, 64, 3, 3)   144.00K
# Parameter480                                           (64,)   512.00B
# Parameter481                                           (64,)   512.00B
# Parameter482                                           (64,)   512.00B
# Tensor483                                              (64,)   512.00B
# Tensor484                                              (64,)   512.00B
# Parameter485                                 (256, 64, 1, 1)    64.00K
# Parameter486                                          (256,)     1.00K
# Parameter487                                          (256,)     1.00K
# Parameter488                                          (256,)     1.00K
# Tensor489                                             (256,)     1.00K
# Tensor490                                             (256,)     1.00K
# Parameter491                                 (64, 256, 1, 1)    64.00K
# Parameter492                                           (64,)   512.00B
# Parameter493                                           (64,)   512.00B
# Parameter494                                           (64,)   512.00B
# Tensor495                                              (64,)   512.00B
# Tensor496                                              (64,)   512.00B
# Parameter497                                  (64, 64, 3, 3)   144.00K
# Parameter498                                           (64,)   512.00B
# Parameter499                                           (64,)   512.00B
# Parameter500                                           (64,)   512.00B
# Tensor501                                              (64,)   512.00B
# Tensor502                                              (64,)   512.00B
# Parameter503                                 (256, 64, 1, 1)    64.00K
# Parameter504                                          (256,)     1.00K
# Parameter505                                          (256,)     1.00K
# Parameter506                                          (256,)     1.00K
# Tensor507                                             (256,)     1.00K
# Tensor508                                             (256,)     1.00K
# Parameter509                                 (256, 64, 1, 1)    64.00K
# Parameter510                                          (256,)     1.00K
# Parameter511                                          (256,)     1.00K
# Parameter512                                          (256,)     1.00K
# Tensor513                                             (256,)     1.00K
# Tensor514                                             (256,)     1.00K
# Parameter515                                           (64,)   512.00B
# Tensor516                                              (64,)   512.00B
# Parameter517                                           (64,)   512.00B
# Parameter518                                           (64,)   512.00B
# Tensor519                                              (64,)   512.00B
# Parameter520                                          (256,)     1.00K
# Parameter521                                          (256,)     1.00K
# Tensor522                                             (256,)     1.00K
# Parameter523                                          (128,)   512.00B
# Tensor524                                             (128,)   512.00B
# Parameter525                                          (128,)   512.00B
# Parameter526                                          (128,)   512.00B
# Tensor527                                             (128,)   512.00B
# Parameter528                                          (512,)     2.00K
# Parameter529                                          (512,)     2.00K
# Tensor530                                             (512,)     2.00K
# Parameter531                                           (64,)   512.00B
# Tensor532                                              (64,)   512.00B
# Parameter533                                  (64, 64, 3, 3)   144.00K
# Parameter534                                           (64,)   512.00B
# Tensor535                                              (64,)   512.00B
# Parameter536                                 (256, 64, 1, 1)    64.00K
# Parameter537                                          (256,)     1.00K
# Tensor538                                             (256,)     1.00K
# Parameter539                                          (128,)   512.00B
# Tensor540                                             (128,)   512.00B
# Parameter541                                (128, 128, 3, 3)   576.00K
# Parameter542                                          (128,)   512.00B
# Tensor543                                             (128,)   512.00B
# Parameter544                                (512, 128, 1, 1)   256.00K
# Parameter545                                          (512,)     2.00K
# Tensor546                                             (512,)     2.00K
# Parameter547                                (256, 768, 1, 1)   768.00K
# Parameter548                                          (256,)     1.00K
# Parameter549                                          (256,)     1.00K
# Parameter550                                          (256,)     1.00K
# Tensor551                                             (256,)     1.00K
# Tensor552                                             (256,)     1.00K
# Parameter553                                (128, 256, 1, 1)   128.00K
# Parameter554                                          (128,)   512.00B
# Parameter555                                (512, 256, 1, 1)   512.00K
# Parameter556                                          (512,)     2.00K
# Parameter557                                          (512,)     2.00K
# Parameter558                                          (512,)     2.00K
# Tensor559                                             (512,)     2.00K
# Tensor560                                             (512,)     2.00K
# Parameter561                               (256, 1024, 1, 1)     1.00M
# Parameter562                                          (256,)     1.00K
# Parameter563                                          (256,)     1.00K
# Parameter564                                          (256,)     1.00K
# Tensor565                                             (256,)     1.00K
# Tensor566                                             (256,)     1.00K
# Parameter567                                (256, 256, 3, 3)     2.25M
# Parameter568                                          (256,)     1.00K
# Parameter569                                          (256,)     1.00K
# Parameter570                                          (256,)     1.00K
# Tensor571                                             (256,)     1.00K
# Tensor572                                             (256,)     1.00K
# Parameter573                               (1024, 256, 1, 1)     1.00M
# Parameter574                                         (1024,)     4.00K
# Parameter575                                         (1024,)     4.00K
# Parameter576                                         (1024,)     4.00K
# Tensor577                                            (1024,)     4.00K
# Tensor578                                            (1024,)     4.00K
# Parameter579                               (256, 1024, 1, 1)     1.00M
# Parameter580                                          (256,)     1.00K
# Parameter581                                          (256,)     1.00K
# Parameter582                                          (256,)     1.00K
# Tensor583                                             (256,)     1.00K
# Tensor584                                             (256,)     1.00K
# Parameter585                                (256, 256, 3, 3)     2.25M
# Parameter586                                          (256,)     1.00K
# Parameter587                                          (256,)     1.00K
# Parameter588                                          (256,)     1.00K
# Tensor589                                             (256,)     1.00K
# Tensor590                                             (256,)     1.00K
# Parameter591                               (1024, 256, 1, 1)     1.00M
# Parameter592                                         (1024,)     4.00K
# Parameter593                                         (1024,)     4.00K
# Parameter594                                         (1024,)     4.00K
# Tensor595                                            (1024,)     4.00K
# Tensor596                                            (1024,)     4.00K
# Parameter597                               (256, 1024, 1, 1)     1.00M
# Parameter598                                          (256,)     1.00K
# Parameter599                                          (256,)     1.00K
# Parameter600                                          (256,)     1.00K
# Tensor601                                             (256,)     1.00K
# Tensor602                                             (256,)     1.00K
# Parameter603                                (256, 256, 3, 3)     2.25M
# Parameter604                                          (256,)     1.00K
# Parameter605                                          (256,)     1.00K
# Parameter606                                          (256,)     1.00K
# Tensor607                                             (256,)     1.00K
# Tensor608                                             (256,)     1.00K
# Parameter609                               (1024, 256, 1, 1)     1.00M
# Parameter610                                         (1024,)     4.00K
# Parameter611                                         (1024,)     4.00K
# Parameter612                                         (1024,)     4.00K
# Tensor613                                            (1024,)     4.00K
# Tensor614                                            (1024,)     4.00K
# Parameter615                                         (1508,)     6.00K
# Parameter616                                    (1508, 2048)    11.78M
# Parameter617                               (512, 2048, 1, 1)     4.00M
# Parameter618                                          (512,)     2.00K
# Parameter619                                          (512,)     2.00K
# Parameter620                                          (512,)     2.00K
# Tensor621                                             (512,)     2.00K
# Tensor622                                             (512,)     2.00K
# Parameter623                                (512, 512, 3, 3)     9.00M
# Parameter624                                          (512,)     2.00K
# Parameter625                                          (512,)     2.00K
# Parameter626                                          (512,)     2.00K
# Tensor627                                             (512,)     2.00K
# Tensor628                                             (512,)     2.00K
# Parameter629                               (2048, 512, 1, 1)     4.00M
# Parameter630                                         (2048,)     8.00K
# Parameter631                                         (2048,)     8.00K
# Parameter632                                         (2048,)     8.00K
# Tensor633                                            (2048,)     8.00K
# Tensor634                                            (2048,)     8.00K
# Parameter635                               (512, 2048, 1, 1)     4.00M
# Parameter636                                          (512,)     2.00K
# Parameter637                                          (512,)     2.00K
# Parameter638                                          (512,)     2.00K
# Tensor639                                             (512,)     2.00K
# Tensor640                                             (512,)     2.00K
# Parameter641                                (512, 512, 3, 3)     9.00M
# Parameter642                                          (512,)     2.00K
# Parameter643                                          (512,)     2.00K
# Parameter644                                          (512,)     2.00K
# Tensor645                                             (512,)     2.00K
# Tensor646                                             (512,)     2.00K
# Parameter647                               (2048, 512, 1, 1)     4.00M
# Parameter648                                         (2048,)     8.00K
# Parameter649                                         (2048,)     8.00K
# Parameter650                                         (2048,)     8.00K
# Tensor651                                            (2048,)     8.00K
# Tensor652                                            (2048,)     8.00K
# Parameter653                                   (64, 3, 7, 7)    37.00K
# Parameter654                                           (64,)   512.00B
# Parameter655                                   (64, 3, 7, 7)    37.00K
# Parameter656                                           (64,)   512.00B
# Parameter657                                           (64,)   512.00B
# Parameter658                                           (64,)   512.00B
# Tensor659                                              (64,)   512.00B
# Tensor660                                              (64,)   512.00B
# Parameter661                                 (64, 768, 1, 1)   192.00K
# Parameter662                                           (64,)   512.00B
# Parameter663                                (256, 512, 1, 1)   512.00K
# Parameter664                                          (256,)     1.00K
# Parameter665                                          (256,)     1.00K
# Parameter666                                          (256,)     1.00K
# Tensor667                                             (256,)     1.00K
# Tensor668                                             (256,)     1.00K
# Parameter669                                (256, 256, 3, 3)     2.25M
# Parameter670                                          (256,)     1.00K
# Parameter671                                          (256,)     1.00K
# ...
# Tensor2050                                              (1,)   512.00B
# Parameter2051                                 (64, 64, 3, 3)   144.00K
# Parameter2052                                          (64,)   512.00B
# Parameter2053                                          (64,)   512.00B
# Tensor2054                                             (64,)   512.00B
# Tensor2055                                             (64,)   512.00B
# Tensor2056                                              (1,)   512.00B
# Parameter2057                                 (64, 64, 3, 3)   144.00K
# Parameter2058                                          (64,)   512.00B
# Parameter2059                                          (64,)   512.00B
# Tensor2060                                             (64,)   512.00B
# Tensor2061                                             (64,)   512.00B
# Tensor2062                                              (1,)   512.00B
# Parameter2063                                (128, 64, 3, 3)   288.00K
# Parameter2064                                         (128,)   512.00B
# Parameter2065                                         (128,)   512.00B
# Tensor2066                                            (128,)   512.00B
# Tensor2067                                            (128,)   512.00B
# Tensor2068                                              (1,)   512.00B
# Parameter2069                               (128, 128, 3, 3)   576.00K
# Parameter2070                                         (128,)   512.00B
# Parameter2071                                         (128,)   512.00B
# Tensor2072                                            (128,)   512.00B
# Tensor2073                                            (128,)   512.00B
# Tensor2074                                              (1,)   512.00B
# Parameter2075                               (128, 128, 3, 3)   576.00K
# Parameter2076                                         (128,)   512.00B
# Parameter2077                                         (128,)   512.00B
# Tensor2078                                            (128,)   512.00B
# Tensor2079                                            (128,)   512.00B
# Tensor2080                                              (1,)   512.00B
# Parameter2081                               (128, 128, 3, 3)   576.00K
# Parameter2082                                         (128,)   512.00B
# Parameter2083                                         (128,)   512.00B
# Tensor2084                                            (128,)   512.00B
# Tensor2085                                            (128,)   512.00B
# Tensor2086                                              (1,)   512.00B
# Parameter2087                               (256, 128, 3, 3)     1.12M
# Parameter2088                                         (256,)     1.00K
# Parameter2089                                         (256,)     1.00K
# Tensor2090                                            (256,)     1.00K
# Tensor2091                                            (256,)     1.00K
# Tensor2092                                              (1,)   512.00B
# Parameter2093                               (256, 256, 3, 3)     2.25M
# Parameter2094                                         (256,)     1.00K
# Parameter2095                                         (256,)     1.00K
# Tensor2096                                            (256,)     1.00K
# Tensor2097                                            (256,)     1.00K
# Tensor2098                                              (1,)   512.00B
# Parameter2099                               (256, 256, 3, 3)     2.25M
# Parameter2100                                         (256,)     1.00K
# Parameter2101                                         (256,)     1.00K
# Tensor2102                                            (256,)     1.00K
# Tensor2103                                            (256,)     1.00K
# Tensor2104                                              (1,)   512.00B
# Parameter2105                               (256, 256, 3, 3)     2.25M
# Parameter2106                                         (256,)     1.00K
# Parameter2107                                         (256,)     1.00K
# Tensor2108                                            (256,)     1.00K
# Tensor2109                                            (256,)     1.00K
# Tensor2110                                              (1,)   512.00B
# Parameter2111                               (512, 256, 3, 3)     4.50M
# Parameter2112                                         (512,)     2.00K
# Parameter2113                                         (512,)     2.00K
# Tensor2114                                            (512,)     2.00K
# Tensor2115                                            (512,)     2.00K
# Tensor2116                                              (1,)   512.00B
# Parameter2117                               (512, 512, 3, 3)     9.00M
# Parameter2118                                         (512,)     2.00K
# Parameter2119                                         (512,)     2.00K
# Tensor2120                                            (512,)     2.00K
# Tensor2121                                            (512,)     2.00K
# Tensor2122                                              (1,)   512.00B
# Parameter2123                               (512, 512, 3, 3)     9.00M
# Parameter2124                                         (512,)     2.00K
# Parameter2125                                         (512,)     2.00K
# Tensor2126                                            (512,)     2.00K
# Tensor2127                                            (512,)     2.00K
# Tensor2128                                              (1,)   512.00B
# Parameter2129                               (512, 512, 3, 3)     9.00M
# Parameter2130                                         (512,)     2.00K
# Parameter2131                                         (512,)     2.00K
# Tensor2132                                            (512,)     2.00K
# Tensor2133                                            (512,)     2.00K
# Tensor2134                                              (1,)   512.00B
# Parameter2135                                 (64, 64, 3, 3)   144.00K
# Parameter2136                                          (64,)   512.00B
# Parameter2137                                          (64,)   512.00B
# Tensor2138                                             (64,)   512.00B
# Tensor2139                                             (64,)   512.00B
# Tensor2140                                              (1,)   512.00B
# Parameter2141                                 (64, 64, 3, 3)   144.00K
# Parameter2142                                          (64,)   512.00B
# Parameter2143                                          (64,)   512.00B
# Tensor2144                                             (64,)   512.00B
# Tensor2145                                             (64,)   512.00B
# Tensor2146                                              (1,)   512.00B
# Parameter2147                                 (64, 64, 3, 3)   144.00K
# Parameter2148                                          (64,)   512.00B
# Parameter2149                                          (64,)   512.00B
# Tensor2150                                             (64,)   512.00B
# Tensor2151                                             (64,)   512.00B
# Tensor2152                                              (1,)   512.00B
# Parameter2153                                 (64, 64, 3, 3)   144.00K
# Parameter2154                                          (64,)   512.00B
# Parameter2155                                          (64,)   512.00B
# Tensor2156                                             (64,)   512.00B
# Tensor2157                                             (64,)   512.00B
# Tensor2158                                              (1,)   512.00B
# Parameter2159                                (128, 64, 3, 3)   288.00K
# Parameter2160                                         (128,)   512.00B
# Parameter2161                                         (128,)   512.00B
# Tensor2162                                            (128,)   512.00B
# Tensor2163                                            (128,)   512.00B
# Tensor2164                                              (1,)   512.00B
# Parameter2165                               (128, 128, 3, 3)   576.00K
# Parameter2166                                         (128,)   512.00B
# Parameter2167                                         (128,)   512.00B
# Tensor2168                                            (128,)   512.00B
# Tensor2169                                            (128,)   512.00B
# Tensor2170                                              (1,)   512.00B
# Parameter2171                               (128, 128, 3, 3)   576.00K
# Parameter2172                                         (128,)   512.00B
# Parameter2173                                         (128,)   512.00B
# Tensor2174                                            (128,)   512.00B
# Tensor2175                                            (128,)   512.00B
# Tensor2176                                              (1,)   512.00B
# Parameter2177                               (128, 128, 3, 3)   576.00K
# Parameter2178                                         (128,)   512.00B
# Parameter2179                                         (128,)   512.00B
# Tensor2180                                            (128,)   512.00B
# Tensor2181                                            (128,)   512.00B
# Tensor2182                                              (1,)   512.00B
# Parameter2183                               (256, 128, 3, 3)     1.12M
# Parameter2184                                         (256,)     1.00K
# Parameter2185                                         (256,)     1.00K
# Tensor2186                                            (256,)     1.00K
# Tensor2187                                            (256,)     1.00K
# Tensor2188                                              (1,)   512.00B
# Parameter2189                               (256, 256, 3, 3)     2.25M
# Parameter2190                                         (256,)     1.00K
# Parameter2191                                         (256,)     1.00K
# Tensor2192                                            (256,)     1.00K
# Tensor2193                                            (256,)     1.00K
# Tensor2194                                              (1,)   512.00B
# Parameter2195                               (256, 256, 3, 3)     2.25M
# Parameter2196                                         (256,)     1.00K
# Parameter2197                                         (256,)     1.00K
# Tensor2198                                            (256,)     1.00K
# Tensor2199                                            (256,)     1.00K
# Tensor2200                                              (1,)   512.00B
# Parameter2201                               (256, 256, 3, 3)     2.25M
# Parameter2202                                         (256,)     1.00K
# Parameter2203                                         (256,)     1.00K
# Tensor2204                                            (256,)     1.00K
# Tensor2205                                            (256,)     1.00K
# Tensor2206                                              (1,)   512.00B
# Parameter2207                               (512, 256, 3, 3)     4.50M
# Parameter2208                                         (512,)     2.00K
# Parameter2209                                         (512,)     2.00K
# Tensor2210                                            (512,)     2.00K
# Tensor2211                                            (512,)     2.00K
# Tensor2212                                              (1,)   512.00B
# Parameter2213                               (512, 512, 3, 3)     9.00M
# Parameter2214                                         (512,)     2.00K
# Parameter2215                                         (512,)     2.00K
# Tensor2216                                            (512,)     2.00K
# Tensor2217                                            (512,)     2.00K
# Tensor2218                                              (1,)   512.00B
# Parameter2219                               (512, 512, 3, 3)     9.00M
# Parameter2220                                         (512,)     2.00K
# Parameter2221                                         (512,)     2.00K
# Tensor2222                                            (512,)     2.00K
# Tensor2223                                            (512,)     2.00K
# Tensor2224                                              (1,)   512.00B
# Parameter2225                               (512, 512, 3, 3)     9.00M
# Parameter2226                                         (512,)     2.00K
# Parameter2227                                         (512,)     2.00K
# Tensor2228                                            (512,)     2.00K
# Tensor2229                                            (512,)     2.00K
# Tensor2230                                              (1,)   512.00B
# Parameter2231                                (128, 64, 1, 1)    32.00K
# Parameter2232                                         (128,)   512.00B
# Parameter2233                                         (128,)   512.00B
# Tensor2234                                            (128,)   512.00B
# Tensor2235                                            (128,)   512.00B
# Tensor2236                                              (1,)   512.00B
# Parameter2237                               (256, 128, 1, 1)   128.00K
# Parameter2238                                         (256,)     1.00K
# Parameter2239                                         (256,)     1.00K
# Tensor2240                                            (256,)     1.00K
# Tensor2241                                            (256,)     1.00K
# Tensor2242                                              (1,)   512.00B
# Parameter2243                               (512, 256, 1, 1)   512.00K
# Parameter2244                                         (512,)     2.00K
# Parameter2245                                         (512,)     2.00K
# Tensor2246                                            (512,)     2.00K
# Tensor2247                                            (512,)     2.00K
# Tensor2248                                              (1,)   512.00B
# Parameter2249                                (128, 64, 1, 1)    32.00K
# Parameter2250                                         (128,)   512.00B
# Parameter2251                                         (128,)   512.00B
# Tensor2252                                            (128,)   512.00B
# Tensor2253                                            (128,)   512.00B
# Tensor2254                                              (1,)   512.00B
# Parameter2255                               (256, 128, 1, 1)   128.00K
# Parameter2256                                         (256,)     1.00K
# Parameter2257                                         (256,)     1.00K
# Tensor2258                                            (256,)     1.00K
# Tensor2259                                            (256,)     1.00K
# Tensor2260                                              (1,)   512.00B
# Parameter2261                               (512, 256, 1, 1)   512.00K
# Parameter2262                                         (512,)     2.00K
# Parameter2263                                         (512,)     2.00K
# Tensor2264                                            (512,)     2.00K
# Tensor2265                                            (512,)     2.00K
# Tensor2266                                              (1,)   512.00B
# -------------------------------------------------------------------------------
# Total Tensors: 542867558 	Used Memory: 2.02G
# -------------------------------------------------------------------------------
# c:\michele\uni\polito\quinto_anno\primo_semestre\ML_vision_multimedia\progetto\mlvm-project\venv\Lib\site-packages\pytorch_memlab\mem_reporter.py:65: FutureWarning: `torch.distributed.reduce_op` is deprecated, please use `torch.distributed.ReduceOp` instead
#   tensors = [obj for obj in objects if isinstance(obj, torch.Tensor)]

# %%
# Input batch of images
artist = model(x)
print("Artist output shape:", artist.shape)
# Out:
# torch.Size([4, 3, 512, 512]) torch.Size([4, 2048]) torch.Size([4, 4056])
# torch.Size([4, 6104])
# Artist output shape: torch.Size([4, 1508])
